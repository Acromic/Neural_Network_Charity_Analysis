# %%
conda create -n tfenv tensorflow
# Out:
# ...
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/wilmaker/opt/anaconda3/envs/mlenv/envs/tfenv
#
#   added / updated specs:
#     - tensorflow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB
#     c-ares-1.18.1              |       hca72f7f_0         100 KB
#     dataclasses-0.8            |     pyh6d0b6a4_7           8 KB
#     grpcio-1.42.0              |   py37ha29bfda_0         1.7 MB
#     importlib-metadata-4.11.3  |   py37hecd8cb5_0          40 KB
#     intel-openmp-2021.4.0      |    hecd8cb5_3538         961 KB
#     libcxx-12.0.0              |       h2f01273_0         805 KB
#     libffi-3.3                 |       hb1e8313_2          44 KB
# ...

# %%
y
